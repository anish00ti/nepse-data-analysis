# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
import random

# Generate a random integer between 1 and 100
random_number = random.randint(1, 100)

# Choose a random item from a list
programming_languages = ["Python", "JavaScript", "C++", "Rust", "Go"]
random_choice = random.choice(programming_languages)

# Print the results
print(f"Your random number is: {random_number}")
print(f"Your random programming language is: {random_choice}")
# Out:
# Your random number is: 41
# Your random programming language is: Rust
